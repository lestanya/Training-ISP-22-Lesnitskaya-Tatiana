# %%
import pandas as pd
import os

# Путь к директории с файлами CSV


# Чтение всех файлов CSV из директории

df = pd.read_csv('/content/drive/MyDrive/таблицы/колонки/kv_db.csv')
df = df.drop(df.columns[[10, 11]], axis=1)

df.to_csv('thirddf.csv', index=False)

# Вывод первых строк объединенной таблицы для проверки
print(df.head())
# Out:
#          Стройинвест representative_developer  \
# 0       Этажи Москва        real_estate_agent
# 1  Александр Кубышев                  realtor
# 2            Самолет                developer
# 3       ID 118582271                homeowner
# 4         ТСН Владис        real_estate_agent
#
#    https://balashikha.cian.ru/sale/flat/305430873/  Балашиха  sale  flat  12  \
# 0  https://balashikha.cian.ru/sale/flat/308583683/  Балашиха  sale  flat  19
# 1  https://balashikha.cian.ru/sale/flat/305822096/  Балашиха  sale  flat   2
# 2  https://balashikha.cian.ru/sale/flat/308722035/  Балашиха  sale  flat  20
# 3  https://balashikha.cian.ru/sale/flat/308939146/  Балашиха  sale  flat  10
# 4  https://balashikha.cian.ru/sale/flat/303023571/  Балашиха  sale  flat   4
#
#    17  1  36.4   6027360 Unnamed: 13         Поликахина    2     Лухмановская  \
# 0  20  2  68.8  12000000         NaN    шоссе Косинское  5/7          Ольгино
# ...

# %%
import pandas as pd
import os

# Путь к директории с файлами CSV


# Чтение всех файлов CSV из директории

df = pd.read_csv('/content/thirddf.csv')


# Объединение всех таблиц


# Переименование колонок (если необходимо)
df.columns = [
'author', 'author_type', 'url', 'location', 'deal_type', 'accommodation_type',
'floor', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district',
'street', 'house_number', 'underground', 'residential_complex'
]

# Сохранение объединенной таблицы в CSV файл


df.to_csv('thirddf.csv', index=False)

# Вывод первых строк объединенной таблицы для проверки
print(df.head())
# Out:
#               author        author_type  \
# 0       Этажи Москва  real_estate_agent
# 1  Александр Кубышев            realtor
# 2            Самолет          developer
# 3       ID 118582271          homeowner
# 4         ТСН Владис  real_estate_agent
#
#                                                url  location deal_type  \
# 0  https://balashikha.cian.ru/sale/flat/308583683/  Балашиха      sale
# 1  https://balashikha.cian.ru/sale/flat/305822096/  Балашиха      sale
# 2  https://balashikha.cian.ru/sale/flat/308722035/  Балашиха      sale
# 3  https://balashikha.cian.ru/sale/flat/308939146/  Балашиха      sale
# 4  https://balashikha.cian.ru/sale/flat/303023571/  Балашиха      sale
#
#   accommodation_type floor floors_count rooms_count total_meters     price  \
# 0               flat    19           20           2         68.8  12000000
# 1               flat     2           16           1         32.0   4900000
# ...

# %%
import pandas as pd
import os

# Путь к директории с файлами CSV
directory_path = '/content/drive/MyDrive/fff'

# Чтение всех файлов CSV из директории
dataframes = []
for filename in os.listdir(directory_path):
  if filename.endswith(".csv"):
    df = pd.read_csv(os.path.join(directory_path, filename), sep=';', on_bad_lines='skip')
    dataframes.append(df)

# Объединение всех таблиц
combined_df = pd.concat(dataframes, ignore_index=True)

# Переименование колонок (если необходимо)
# combined_df.columns = [
# 'author', 'author_type', 'url', 'location', 'deal_type', 'accommodation_type',
# 'floor', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district',
# 'street', 'house_number', 'underground', 'residential_complex'
# ]

# Сохранение объединенной таблицы в CSV файл
combined_df.to_csv('combined_data.csv', index=False)

# Вывод первых строк объединенной таблицы для проверки
print(combined_df.head())
# Out:
#           author        author_type                                       url  \
# 0         Sminex          developer  https://www.cian.ru/sale/flat/306341785/
# 1  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/308553460/
# 2       MR Group          developer  https://www.cian.ru/sale/flat/308909118/
# 3  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/302398135/
# 4         Sminex          developer  https://www.cian.ru/sale/flat/293713880/
#
#   location deal_type accommodation_type  floor  floors_count  rooms_count  \
# 0   Москва      sale               flat      2            12            1
# 1   Москва      sale               flat      9            12            2
# 2   Москва      sale               flat      6            13            2
# 3   Москва      sale               flat      5            17            3
# 4   Москва      sale               flat      2            14            2
#
# ...

# %%
combined_df.head()
# Out:
#           author        author_type                                       url  \
# 0         Sminex          developer  https://www.cian.ru/sale/flat/306341785/
# 1  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/308553460/
# 2       MR Group          developer  https://www.cian.ru/sale/flat/308909118/
# 3  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/302398135/
# 4         Sminex          developer  https://www.cian.ru/sale/flat/293713880/
#
#   location deal_type accommodation_type  floor  floors_count  rooms_count  \
# 0   Москва      sale               flat      2            12            1
# 1   Москва      sale               flat      9            12            2
# 2   Москва      sale               flat      6            13            2
# 3   Москва      sale               flat      5            17            3
# 4   Москва      sale               flat      2            14            2
#
# ...

# %%
directory_path = '/content/drive/MyDrive/таблицы'

# Чтение всех файлов CSV из директории
dataframes = []
for filename in os.listdir(directory_path):
  if filename.endswith(".csv"):
    df = pd.read_csv(os.path.join(directory_path, filename), on_bad_lines='skip')
    dataframes.append(df)

# Объединение всех таблиц
combined_df = pd.concat(dataframes, ignore_index=True)

# Переименование колонок (если необходимо)


# Сохранение объединенной таблицы в CSV файл
combined_df.to_csv('cian_data.csv', index=False)

# Вывод первых строк объединенной таблицы для проверки
print(combined_df.head())
# Out:
#           author        author_type                                       url  \
# 0         Sminex          developer  https://www.cian.ru/sale/flat/306341785/
# 1  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/308553460/
# 2       MR Group          developer  https://www.cian.ru/sale/flat/308909118/
# 3  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/302398135/
# 4         Sminex          developer  https://www.cian.ru/sale/flat/293713880/
#
#   location deal_type accommodation_type floor floors_count rooms_count  \
# 0   Москва      sale               flat     2           12           1
# 1   Москва      sale               flat     9           12           2
# 2   Москва      sale               flat     6           13           2
# 3   Москва      sale               flat     5           17           3
# 4   Москва      sale               flat     2           14           2
#
# ...

# %%
df = pd.read_csv('/content/cian_data.csv')


# Объединение всех таблиц


df.drop_duplicates()

# Сохранение объединенной таблицы в CSV файл


df.to_csv('cian_sale_df.csv', index=False)

# Вывод первых строк объединенной таблицы для проверки
print(df.head())
# Out:
#           author        author_type                                       url  \
# 0         Sminex          developer  https://www.cian.ru/sale/flat/306341785/
# 1  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/308553460/
# 2       MR Group          developer  https://www.cian.ru/sale/flat/308909118/
# 3  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/302398135/
# 4         Sminex          developer  https://www.cian.ru/sale/flat/293713880/
#
#   location deal_type accommodation_type floor floors_count rooms_count  \
# 0   Москва      sale               flat     2           12           1
# 1   Москва      sale               flat     9           12           2
# 2   Москва      sale               flat     6           13           2
# 3   Москва      sale               flat     5           17           3
# 4   Москва      sale               flat     2           14           2
#
# ...

# %%
df.head()
# Out:
#           author        author_type                                       url  \
# 0         Sminex          developer  https://www.cian.ru/sale/flat/306341785/
# 1  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/308553460/
# 2       MR Group          developer  https://www.cian.ru/sale/flat/308909118/
# 3  Kalinka Group  real_estate_agent  https://www.cian.ru/sale/flat/302398135/
# 4         Sminex          developer  https://www.cian.ru/sale/flat/293713880/
#
#   location deal_type accommodation_type floor floors_count rooms_count  \
# 0   Москва      sale               flat     2           12           1
# 1   Москва      sale               flat     9           12           2
# 2   Москва      sale               flat     6           13           2
# 3   Москва      sale               flat     5           17           3
# 4   Москва      sale               flat     2           14           2
#
# ...
