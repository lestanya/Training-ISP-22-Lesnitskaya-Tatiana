# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/с доп.данными/ready_all_df (2).csv')
df.head()
# Out:
#                               author        author_type  \
# 0                       ID 115709096          homeowner
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                         ID 3246838            realtor
# 3                        ID 64398571            unknown
# 4                          ЛИДЕРМЭЙН  real_estate_agent
#
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0               flat     6            6           1         20.7  ...
# 1               flat     1            9           1         33.0  ...
# 2               flat     4            4           1         14.0  ...
# 3               flat     5            5           1         17.5  ...
# 4               flat     4            7           1         25.9  ...
#
#   finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0          -1         18 м²           1 м²  79175096253            3 м
# 1          -1         18 м²           6 м²  79645530086          2,7 м
# 2          -1            -1             -1  79807126116             -1
# 3          -1            -1             -1  79645652380             -1
# 4          -1         20 м²           5 м²  79099408093          3,5 м
#
#                   district                street house_number underground  \
# 0                 Серпухов               Крюкова            4         NaN
# 1                      NaN            Ворошилова          144      Аннино
# 2  Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                 Серпухов           Российская            40         NaN
# 4                 Серпухов               Химиков            8         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10391 entries, 0 to 10390
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9562 non-null   object
#  1   author_type           9571 non-null   object
#  2   url                   9904 non-null   object
#  3   location              9904 non-null   object
#  4   deal_type             9904 non-null   object
#  5   accommodation_type    9904 non-null   object
#  6   floor                 9904 non-null   object
#  7   floors_count          9904 non-null   object
#  8   rooms_count           9904 non-null   object
#  9   total_meters          9904 non-null   object
#  10  price                 9891 non-null   object
#  11  year_of_construction  7906 non-null   object
#  12  object_type           7906 non-null   object
#  13  have_loggia           7906 non-null   object
#  14  parking_type          7906 non-null   object
#  15  house_material_type   7906 non-null   object
#  16  heating_type          7906 non-null   object
#  17  finish_type           7906 non-null   object
#  18  living_meters         7906 non-null   object
#  19  kitchen_meters        7906 non-null   object
#  20  phone                 7906 non-null   object
#  21  ceiling_height        7906 non-null   object
#  22  district              3909 non-null   object
#  23  street                8124 non-null   object
#  24  house_number          8605 non-null   object
#  25  underground           6860 non-null   object
#  26  residential_complex   4794 non-null   object
# dtypes: object(27)
# memory usage: 2.1+ MB

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'url', 'location', 'deal_type',
#        'accommodation_type', 'floor', 'floors_count', 'rooms_count',
#        'total_meters', 'price', 'year_of_construction', 'object_type',
#        'have_loggia', 'parking_type', 'house_material_type', 'heating_type',
#        'finish_type', 'living_meters', 'kitchen_meters', 'phone',
#        'ceiling_height', 'district', 'street', 'house_number', 'underground',
#        'residential_complex'],
#       dtype='object')

# %% [markdown]
# # **Названия колонок**
#
#
#   author - автор
#
#   author_type - тип автора
#
#   url - URL
#
#   location - местоположение
#
#   deal_type - тип сделки
#
#   accommodation_type - тип жилья
#
#   floor - этаж
#
#   floors_count - количество этажей
#
#   rooms_count - количество комнат
#
#   total_meters - общая площадь
#
#   price - цена
#
#   year_of_construction - год постройки
#
#   object_type - тип объекта
#
#   have_loggia - есть лоджия
#
#   parking_type - тип парковки
#
#   house_material_type - тип материала дома
#
#   heating_type - тип отопления
#
#   finish_type - тип отделки
#
#   living_meters - жилая площадь
#
#   kitchen_meters - площадь кухни
#
#   phone - телефон
#
#   ceiling_height - высота потолков
#
#   district - район
#
#   street - улица
#
#   house_number - номер дома
#
#   underground - метро
#
#   residential_complex - жилой комплекс

# %% [markdown]
# # Очистка данных

# %% [markdown]
# Очистка от дубликатов

# %%
number_of_duplicates = df.duplicated().sum()
print(f'Количество дубликатов {number_of_duplicates}')
# Out:
# Количество дубликатов 816

# %%
df.drop_duplicates(inplace=True)
print(f'Осталось {df.shape[0]} строчек ')
# Out:
# Осталось 9575 строчек

# %%
number_of_duplicates = df.duplicated().sum()
print(f'Количество дубликатов {number_of_duplicates}')
# Out:
# Количество дубликатов 0

# %% [markdown]
# видим, что график не соответствует реальности. heating type отсутствует, а все потому что пустые значения заполнены -1 а не nan

# %%
sns.heatmap(df.isnull(), cmap='prism')
# Out:
# <Axes: >

# %% [markdown]
# Надо заменить все значения '-1' на np.nan в каждой колонке

# %%
for column in df.columns:
  df[column].replace('-1', np.nan, inplace=True)
# Out:
# <ipython-input-10-55f6ffa464a1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].replace('-1', np.nan, inplace=True)

# %% [markdown]
# Теперь уже больше похоже на правду. Теперь мы явно видим что вся колонка heating_type отсутствует

# %%
sns.heatmap(df.isnull(), cmap='prism')
# Out:
# <Axes: >

# %% [markdown]
# Необходимы точные значения в процентах, чтобы понять от каких колонок можно избавиться
# Нет смысла работать с колонками, где значения отсутствуют больше чем на 70%

# %%
procentage = (df.isnull().sum() / len(df)*100).astype(int)
sort = procentage.sort_values(ascending=False)
sort
# Out:
# heating_type            99
# house_material_type     85
# finish_type             80
# district                60
# parking_type            55
# have_loggia             54
# residential_complex     51
# ceiling_height          48
# living_meters           38
# year_of_construction    34
# kitchen_meters          34
# underground             30
# phone                   20
# object_type             20
# street                  17
# house_number            12
# author                   3
# author_type              3
# rooms_count              1
# url                      0
# floors_count             0
# deal_type                0
# accommodation_type       0
# floor                    0
# price                    0
# total_meters             0
# location                 0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# heating_type            9574
# house_material_type     8189
# finish_type             7666
# district                5799
# parking_type            5332
# have_loggia             5241
# residential_complex     4953
# ceiling_height          4662
# living_meters           3699
# year_of_construction    3313
# kitchen_meters          3275
# underground             2926
# object_type             1999
# phone                   1999
# street                  1704
# house_number            1225
# author                   329
# author_type              320
# rooms_count               97
# price                     14
# url                        1
# floors_count               1
# deal_type                  1
# accommodation_type         1
# floor                      1
# total_meters               1
# location                   1
# dtype: int64

# %% [markdown]
# Все что **выше 75** процентов необходимо удалить.
# Значит, необходимо удалить колонки `**heating_type**` и `**house_material_type**`  и  **`'finish_type'`**
# А также house_number, url и phone

# %%
useless_columns = ['house_material_type', 'heating_type', 'finish_type', 'house_number', 'url', 'phone']
for column in useless_columns:
  df.drop([column], axis=1, inplace=True)

# %%
sns.heatmap(df.isnull(), cmap='prism')
# Out:
# <Axes: >

# %% [markdown]
# # Не все колонки имеют нужные типы.
# **Нужно** понять какие можно оставить типом object а какие преобразовать в int и float**
#
#
# ```
# object: 'author', 'author_type', 'url', 'location', 'deal_type',
#        'accommodation_type', 'object_type' : object,
#        'have_loggia' : object, 'parking_type' : object, 'finish_type' : object,  'phone' : object, , 'district' : object, 'street' : object,
#        'house_number', 'underground' : object, 'residential_complex' : object
#
#
# int: 'floors_count', 'rooms_count', 'price', 'floor', 'year_of_construction'
#
# float:  'total_meters', 'living_meters',
#        'kitchen_meters', 'ceiling_height'
#
# ```

# %% [markdown]
# Прежде чем преобразовать в числовой формат, колонки 'living_meters',
#        'kitchen_meters', 'ceiling_height' изменить и убрать обозначение м

# %%
df.head()
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters    price  \
# 0               flat     6            6           1         20.7  2350000
# 1               flat     1            9           1         33.0  4150000
# 2               flat     4            4           1         14.0  1700000
# 3               flat     5            5           1         17.5  2500000
# 4               flat     4            7           1         25.9  3000000
#
#    ... object_type have_loggia parking_type living_meters kitchen_meters  \
# 0  ...    Вторичка         NaN     Наземная         18 м²           1 м²
# 1  ...    Вторичка         NaN          NaN         18 м²           6 м²
# 2  ...    Вторичка         NaN          NaN           NaN            NaN
# 3  ...    Вторичка         NaN          NaN           NaN            NaN
# 4  ...    Вторичка         NaN     Наземная         20 м²           5 м²
#
#   ceiling_height                 district                street underground  \
# 0            3 м                 Серпухов               Крюкова         NaN
# 1          2,7 м                      NaN            Ворошилова      Аннино
# 2            NaN  Красный Текстильщик мкр   Красный Текстильщик         NaN
# 3            NaN                 Серпухов           Российская          NaN
# 4          3,5 м                 Серпухов               Химиков         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 21 columns]

# %%
# df['living_meters'] = df['living_meters'].str.replace('\xa0м²', '').str.replace(',', '.').astype(float)
# df['kitchen_meters'] = df['kitchen_meters'].str.replace('\xa0м²', '').str.replace(',', '.').astype(float)
# df['ceiling_height'] = df['ceiling_height'].str.replace('\xa0м', '').str.replace(',', '.').astype(float)

df['living_meters'] = df['living_meters'].str.replace(',', '.')
df['kitchen_meters'] = df['kitchen_meters'].str.replace(',', '.')
df['ceiling_height'] = df['ceiling_height'].str.replace(',', '.')

# %%
df['living_meters'] = df['living_meters'].str.replace('\xa0м²', '')
df['kitchen_meters'] = df['kitchen_meters'].str.replace('\xa0м²', '')
df['ceiling_height'] = df['ceiling_height'].str.replace('\xa0м', '')

# %%
df.head()
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters    price  \
# 0               flat     6            6           1         20.7  2350000
# 1               flat     1            9           1         33.0  4150000
# 2               flat     4            4           1         14.0  1700000
# 3               flat     5            5           1         17.5  2500000
# 4               flat     4            7           1         25.9  3000000
#
#    ... object_type have_loggia parking_type living_meters kitchen_meters  \
# 0  ...    Вторичка         NaN     Наземная            18              1
# 1  ...    Вторичка         NaN          NaN            18              6
# 2  ...    Вторичка         NaN          NaN           NaN            NaN
# 3  ...    Вторичка         NaN          NaN           NaN            NaN
# 4  ...    Вторичка         NaN     Наземная            20              5
#
#   ceiling_height                 district                street underground  \
# 0              3                 Серпухов               Крюкова         NaN
# 1            2.7                      NaN            Ворошилова      Аннино
# 2            NaN  Красный Текстильщик мкр   Красный Текстильщик         NaN
# 3            NaN                 Серпухов           Российская          NaN
# 4            3.5                 Серпухов               Химиков         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 21 columns]

# %%
numeric = ['floors_count', 'rooms_count', 'floor', 'total_meters', 'living_meters', 'kitchen_meters', 'ceiling_height', 'price', 'year_of_construction']

for column in numeric:
  df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9575 entries, 0 to 10390
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9246 non-null   object
#  1   author_type           9255 non-null   object
#  2   location              9574 non-null   object
#  3   deal_type             9574 non-null   object
#  4   accommodation_type    9574 non-null   object
#  5   floor                 9573 non-null   float64
#  6   floors_count          9573 non-null   float64
#  7   rooms_count           9477 non-null   float64
#  8   total_meters          9573 non-null   float64
#  9   price                 9560 non-null   float64
#  10  year_of_construction  6209 non-null   float64
#  11  object_type           7576 non-null   object
#  12  have_loggia           4334 non-null   object
#  13  parking_type          4243 non-null   object
#  14  living_meters         5875 non-null   float64
#  15  kitchen_meters        6299 non-null   float64
#  16  ceiling_height        4912 non-null   float64
#  17  district              3776 non-null   object
#  18  street                7871 non-null   object
#  19  underground           6649 non-null   object
#  20  residential_complex   4622 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0               flat    6.0           6.0          1.0          20.7
# 1               flat    1.0           9.0          1.0          33.0
# 2               flat    4.0           4.0          1.0          14.0
# 3               flat    5.0           5.0          1.0          17.5
# 4               flat    4.0           7.0          1.0          25.9
#
#        price  ...  object_type have_loggia parking_type living_meters  \
# 0  2350000.0  ...     Вторичка         NaN     Наземная          18.0
# 1  4150000.0  ...     Вторичка         NaN          NaN          18.0
# 2  1700000.0  ...     Вторичка         NaN          NaN           NaN
# 3  2500000.0  ...     Вторичка         NaN          NaN           NaN
# 4  3000000.0  ...     Вторичка         NaN     Наземная          20.0
#
#    kitchen_meters  ceiling_height                 district  \
# 0             1.0             3.0                 Серпухов
# 1             6.0             2.7                      NaN
# 2             NaN             NaN  Красный Текстильщик мкр
# 3             NaN             NaN                 Серпухов
# 4             5.0             3.5                 Серпухов
#
#                  street underground residential_complex
# 0               Крюкова         NaN                 NaN
# 1            Ворошилова      Аннино                 NaN
# 2   Красный Текстильщик         NaN                 NaN
# 3           Российская          NaN                 NaN
# 4               Химиков         NaN                 NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # Проверка на выбросы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9575 entries, 0 to 10390
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9246 non-null   object
#  1   author_type           9255 non-null   object
#  2   location              9574 non-null   object
#  3   deal_type             9574 non-null   object
#  4   accommodation_type    9574 non-null   object
#  5   floor                 9573 non-null   float64
#  6   floors_count          9573 non-null   float64
#  7   rooms_count           9477 non-null   float64
#  8   total_meters          9573 non-null   float64
#  9   price                 9560 non-null   float64
#  10  year_of_construction  6209 non-null   float64
#  11  object_type           7576 non-null   object
#  12  have_loggia           4334 non-null   object
#  13  parking_type          4243 non-null   object
#  14  living_meters         5875 non-null   float64
#  15  kitchen_meters        6299 non-null   float64
#  16  ceiling_height        4912 non-null   float64
#  17  district              3776 non-null   object
#  18  street                7871 non-null   object
#  19  underground           6649 non-null   object
#  20  residential_complex   4622 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'location', 'deal_type', 'accommodation_type',
#        'floor', 'floors_count', 'rooms_count', 'total_meters', 'price',
#        'year_of_construction', 'object_type', 'have_loggia', 'parking_type',
#        'living_meters', 'kitchen_meters', 'ceiling_height', 'district',
#        'street', 'underground', 'residential_complex'],
#       dtype='object')

# %%
possible_outliers = df[[ 'floor', 'floors_count',
                     'rooms_count', 'total_meters', 'price',
                    'year_of_construction', 'living_meters',
                    'kitchen_meters', 'ceiling_height']]



possible_outliers
# Out:
#        floor  floors_count  rooms_count  total_meters       price  \
# 0        6.0           6.0          1.0          20.7   2350000.0
# 1        1.0           9.0          1.0          33.0   4150000.0
# 2        4.0           4.0          1.0          14.0   1700000.0
# 3        5.0           5.0          1.0          17.5   2500000.0
# 4        4.0           7.0          1.0          25.9   3000000.0
# ...      ...           ...          ...           ...         ...
# 10386   23.0          24.0          1.0          38.5   9363008.0
# 10387    1.0           3.0          2.0          43.3   5750000.0
# 10388    8.0           8.0          2.0          60.0   9200000.0
# 10389    3.0          19.0          2.0          58.0   8200000.0
# 10390   23.0          25.0          2.0          59.5  14845250.0
#
#        year_of_construction  living_meters  kitchen_meters  ceiling_height
# 0                    1917.0           18.0             1.0             3.0
# 1                    1975.0           18.0             6.0             2.7
# 2                       NaN            NaN             NaN             NaN
# 3                    1968.0            NaN             NaN             NaN
# 4                    2009.0           20.0             5.0             3.5
# ...                     ...            ...             ...             ...
# 10386                   NaN            NaN             NaN             NaN
# 10387                   NaN            NaN             NaN             NaN
# 10388                   NaN            NaN             NaN             NaN
# 10389                   NaN            NaN             NaN             NaN
# 10390                   NaN            NaN             NaN             NaN
#
# [9575 rows x 9 columns]

# %%
outlier_cols = []

for column in possible_outliers.columns:
    # Calculate the IQR (Interquartile Range)
    Q1 = possible_outliers[column].quantile(0.25)
    Q3 = possible_outliers[column].quantile(0.75)
    IQR = Q3 - Q1

    # Identify outliers based on the IQR
    outliers = (possible_outliers[column] < Q1 - 1.5 * IQR) | (possible_outliers[column] > Q3 + 1.5 * IQR)

    # Check if there are any outliers in the column
    if any(outliers):
        outlier_cols.append(column)

# Print columns with outliers
print("Колонки с выбросами:", outlier_cols)
# Out:
# Колонки с выбросами: ['floor', 'floors_count', 'rooms_count', 'total_meters', 'price', 'year_of_construction', 'living_meters', 'kitchen_meters', 'ceiling_height']

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# Создание box plots для каждого столбца
for i, column in enumerate(possible_outliers.columns):
    row = i // 3
    col = i % 3
    sns.boxplot(x=possible_outliers[column], ax=axes[row, col], color='skyblue')
    axes[row, col].set_title(f'Box Plot for {column}')


plt.subplots_adjust(hspace=0.9)
plt.tight_layout()
plt.show()

# %%
possible_outliers
# Out:
#        floor  floors_count  rooms_count  total_meters       price  \
# 0        6.0           6.0          1.0          20.7   2350000.0
# 1        1.0           9.0          1.0          33.0   4150000.0
# 2        4.0           4.0          1.0          14.0   1700000.0
# 3        5.0           5.0          1.0          17.5   2500000.0
# 4        4.0           7.0          1.0          25.9   3000000.0
# ...      ...           ...          ...           ...         ...
# 10386   23.0          24.0          1.0          38.5   9363008.0
# 10387    1.0           3.0          2.0          43.3   5750000.0
# 10388    8.0           8.0          2.0          60.0   9200000.0
# 10389    3.0          19.0          2.0          58.0   8200000.0
# 10390   23.0          25.0          2.0          59.5  14845250.0
#
#        year_of_construction  living_meters  kitchen_meters  ceiling_height
# 0                    1917.0           18.0             1.0             3.0
# 1                    1975.0           18.0             6.0             2.7
# 2                       NaN            NaN             NaN             NaN
# 3                    1968.0            NaN             NaN             NaN
# 4                    2009.0           20.0             5.0             3.5
# ...                     ...            ...             ...             ...
# 10386                   NaN            NaN             NaN             NaN
# 10387                   NaN            NaN             NaN             NaN
# 10388                   NaN            NaN             NaN             NaN
# 10389                   NaN            NaN             NaN             NaN
# 10390                   NaN            NaN             NaN             NaN
#
# [9575 rows x 9 columns]

# %% [markdown]
# Удаляем выбросы и выводим график

# %%
def detect_outliers_iqr(possible_outliers, column):
    Q1 = possible_outliers[column].quantile(0.25)
    Q3 = possible_outliers[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = possible_outliers[(possible_outliers[column] < lower_bound) | (possible_outliers[column] > upper_bound)]
    return outliers

# функцияя для удаления выбросов
def remove_outliers(possible_outliers, column):
    outliers = detect_outliers_iqr(possible_outliers, column)
    possible_outliers = possible_outliers.drop(outliers.index)
    return possible_outliers

# список количественных переменных
quantitative_columns = ['total_meters', 'price', 'living_meters', 'kitchen_meters', 'ceiling_height']

# категориальные переменные
categorical_columns = ['floor', 'floors_count', 'rooms_count', 'year_of_construction']

# визуализация
def visualize_outliers(possible_outliers, column):
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=possible_outliers[column], color='skyblue')
    plt.title(f'Box Plot for {column}')
    plt.show()

# Определение и удаление выбросов
for column in quantitative_columns + categorical_columns:
    possible_outliers = remove_outliers(possible_outliers, column)
    visualize_outliers(possible_outliers, column)

# Вывод обработанных данных
print("Обработанные данные:")
print(possible_outliers)
# Out:
# Обработанные данные:
#        floor  floors_count  rooms_count  total_meters      price  \
# 1        1.0           9.0          1.0          33.0  4150000.0
# 2        4.0           4.0          1.0          14.0  1700000.0
# 3        5.0           5.0          1.0          17.5  2500000.0
# 5        2.0           3.0          1.0          46.7  6599999.0
# 8        1.0           2.0          1.0          27.1  1900000.0
# ...      ...           ...          ...           ...        ...
# 10384    7.0          16.0          1.0          38.8  6290000.0
# 10385    4.0          12.0          2.0          53.6  9300000.0
# 10387    1.0           3.0          2.0          43.3  5750000.0
# 10388    8.0           8.0          2.0          60.0  9200000.0
# 10389    3.0          19.0          2.0          58.0  8200000.0
#
#        year_of_construction  living_meters  kitchen_meters  ceiling_height
# 1                    1975.0           18.0             6.0             2.7
# 2                       NaN            NaN             NaN             NaN
# 3                    1968.0            NaN             NaN             NaN
# 5                       NaN           25.0             6.0             NaN
# 8                    1969.0           18.0             6.0             2.5
# ...                     ...            ...             ...             ...
# 10384                   NaN            NaN             NaN             NaN
# 10385                   NaN            NaN             NaN             NaN
# 10387                   NaN            NaN             NaN             NaN
# 10388                   NaN            NaN             NaN             NaN
# 10389                   NaN            NaN             NaN             NaN
#
# [7379 rows x 9 columns]

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# Создание box plots для каждого столбца
for i, column in enumerate(possible_outliers.columns):
    row = i // 3
    col = i % 3
    sns.boxplot(x=possible_outliers[column], ax=axes[row, col], color='skyblue')
    axes[row, col].set_title(f'Box Plot for {column}')


plt.subplots_adjust(hspace=0.9)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (9575, 21)

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'location', 'deal_type', 'accommodation_type',
#        'floor', 'floors_count', 'rooms_count', 'total_meters', 'price',
#        'year_of_construction', 'object_type', 'have_loggia', 'parking_type',
#        'living_meters', 'kitchen_meters', 'ceiling_height', 'district',
#        'street', 'underground', 'residential_complex'],
#       dtype='object')

# %%
df.describe()
# Out:
#              floor  floors_count  rooms_count  total_meters         price  \
# count  9573.000000   9573.000000  9477.000000   9573.000000  9.560000e+03
# mean      7.326126     13.890630     1.703598     50.775833  1.362327e+07
# std       6.501501      9.094196     0.781568     27.474646  4.160334e+07
# min       1.000000      1.000000    -1.000000     10.800000  8.300000e+05
# 25%       3.000000      6.000000     1.000000     36.000000  5.400000e+06
# 50%       5.000000     14.000000     2.000000     44.700000  7.750000e+06
# 75%      10.000000     18.000000     2.000000     59.200000  1.090000e+07
# max      82.000000    125.000000     5.000000    590.300000  2.361200e+09
#
#        year_of_construction  living_meters  kitchen_meters  ceiling_height
# count           6209.000000    5875.000000     6299.000000     4912.000000
# mean            2006.099372      27.437719       10.538324        2.828031
# std               23.984940      15.643088        5.857255        0.826707
# min             1600.000000       3.000000        1.000000        0.000000
# 25%             1990.000000      17.000000        6.700000        2.700000
# 50%             2016.000000      25.000000        9.500000        2.750000
# 75%             2024.000000      34.000000       12.100000        2.900000
# max             2031.000000     300.000000       90.000000       52.000000

# %% [markdown]
# Одним из подозрительных значений является количество этажей, равное 125.
#
# Но конечно такое возможно в мире, и эти данные могут быть из Москвы.
#
# И то, что возможно, не видно на графиках как выброс это 50 м высота полока.

# %% [markdown]
# Надо заполнить числовые данные с помощью медианы

# %%
median = ['total_meters', 'living_meters', 'kitchen_meters',
          'ceiling_height', 'price']

for m in median:
  df[m] = df[m].fillna(df[m].median())

# %%
sns.heatmap(df.isnull(), cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# Категориальные заполняем модой

# %%
columns_to_fill = ['floors_count', 'rooms_count', 'floor']


for column in columns_to_fill:
    mode_value = df[column].mode()[0]
    df[column] = df[column].fillna(mode_value)

# %%
median_value = df['year_of_construction'].median()
median_value = int(median_value)


df['year_of_construction'] = df['year_of_construction'].fillna(median_value)

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'location', 'deal_type', 'accommodation_type',
#        'floor', 'floors_count', 'rooms_count', 'total_meters', 'price',
#        'year_of_construction', 'object_type', 'have_loggia', 'parking_type',
#        'living_meters', 'kitchen_meters', 'ceiling_height', 'district',
#        'street', 'underground', 'residential_complex'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(), cmap='cividis')
# Out:
# <Axes: >

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# district                5799
# parking_type            5332
# have_loggia             5241
# residential_complex     4953
# underground             2926
# object_type             1999
# street                  1704
# author                   329
# author_type              320
# accommodation_type         1
# deal_type                  1
# location                   1
# total_meters               0
# price                      0
# rooms_count                0
# floors_count               0
# floor                      0
# living_meters              0
# kitchen_meters             0
# ceiling_height             0
# year_of_construction       0
# dtype: int64

# %%
df.head()
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0               flat    6.0           6.0          1.0          20.7
# 1               flat    1.0           9.0          1.0          33.0
# 2               flat    4.0           4.0          1.0          14.0
# 3               flat    5.0           5.0          1.0          17.5
# 4               flat    4.0           7.0          1.0          25.9
#
#        price  ...  object_type have_loggia parking_type living_meters  \
# 0  2350000.0  ...     Вторичка         NaN     Наземная          18.0
# 1  4150000.0  ...     Вторичка         NaN          NaN          18.0
# 2  1700000.0  ...     Вторичка         NaN          NaN          25.0
# 3  2500000.0  ...     Вторичка         NaN          NaN          25.0
# 4  3000000.0  ...     Вторичка         NaN     Наземная          20.0
#
#    kitchen_meters  ceiling_height                 district  \
# 0             1.0            3.00                 Серпухов
# 1             6.0            2.70                      NaN
# 2             9.5            2.75  Красный Текстильщик мкр
# 3             9.5            2.75                 Серпухов
# 4             5.0            3.50                 Серпухов
#
#                  street underground residential_complex
# 0               Крюкова         NaN                 NaN
# 1            Ворошилова      Аннино                 NaN
# 2   Красный Текстильщик         NaN                 NaN
# 3           Российская          NaN                 NaN
# 4               Химиков         NaN                 NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Осталось только заполнить все другие категориальные колонки

# %%
cat_columns = ['object_type', 'have_loggia', 'parking_type', 'district',
       'street', 'underground', 'residential_complex', 'author',
               'author_type',	'accommodation_type',	'deal_type', 'location']


for column in cat_columns:
     df[column] = df[column].apply(lambda x: 'unknown' if pd.isna(x) else x)

# %%
sns.heatmap(df.isnull(), cmap='cividis')
# Out:
# <Axes: >

# %%
df.head(5)
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0               flat    6.0           6.0          1.0          20.7
# 1               flat    1.0           9.0          1.0          33.0
# 2               flat    4.0           4.0          1.0          14.0
# 3               flat    5.0           5.0          1.0          17.5
# 4               flat    4.0           7.0          1.0          25.9
#
#        price  ...  object_type have_loggia parking_type living_meters  \
# 0  2350000.0  ...     Вторичка     unknown     Наземная          18.0
# 1  4150000.0  ...     Вторичка     unknown      unknown          18.0
# 2  1700000.0  ...     Вторичка     unknown      unknown          25.0
# 3  2500000.0  ...     Вторичка     unknown      unknown          25.0
# 4  3000000.0  ...     Вторичка     unknown     Наземная          20.0
#
#    kitchen_meters  ceiling_height                 district  \
# 0             1.0            3.00                 Серпухов
# 1             6.0            2.70                  unknown
# 2             9.5            2.75  Красный Текстильщик мкр
# 3             9.5            2.75                 Серпухов
# 4             5.0            3.50                 Серпухов
#
#                  street underground residential_complex
# 0               Крюкова     unknown             unknown
# 1            Ворошилова      Аннино             unknown
# 2   Красный Текстильщик     unknown             unknown
# 3           Российская      unknown             unknown
# 4               Химиков     unknown             unknown
#
# [5 rows x 21 columns]

# %% [markdown]
# Теперь с уверенностью можно сказать что в датасете нет пропусков

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# author                  0
# object_type             0
# underground             0
# street                  0
# district                0
# ceiling_height          0
# kitchen_meters          0
# living_meters           0
# parking_type            0
# have_loggia             0
# year_of_construction    0
# author_type             0
# price                   0
# total_meters            0
# rooms_count             0
# floors_count            0
# floor                   0
# accommodation_type      0
# deal_type               0
# location                0
# residential_complex     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'location', 'deal_type', 'accommodation_type',
#        'floor', 'floors_count', 'rooms_count', 'total_meters', 'price',
#        'year_of_construction', 'object_type', 'have_loggia', 'parking_type',
#        'living_meters', 'kitchen_meters', 'ceiling_height', 'district',
#        'street', 'underground', 'residential_complex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9575 entries, 0 to 10390
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9575 non-null   object
#  1   author_type           9575 non-null   object
#  2   location              9575 non-null   object
#  3   deal_type             9575 non-null   object
#  4   accommodation_type    9575 non-null   object
#  5   floor                 9575 non-null   float64
#  6   floors_count          9575 non-null   float64
#  7   rooms_count           9575 non-null   float64
#  8   total_meters          9575 non-null   float64
#  9   price                 9575 non-null   float64
#  10  year_of_construction  9575 non-null   float64
#  11  object_type           9575 non-null   object
#  12  have_loggia           9575 non-null   object
#  13  parking_type          9575 non-null   object
#  14  living_meters         9575 non-null   float64
#  15  kitchen_meters        9575 non-null   float64
#  16  ceiling_height        9575 non-null   float64
#  17  district              9575 non-null   object
#  18  street                9575 non-null   object
#  19  underground           9575 non-null   object
#  20  residential_complex   9575 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.9+ MB

# %% [markdown]
# Теперь можно привести некоторые колонки из float в int так как это должно быть целое число

# %%
to_int_columns = ['floor', 'floors_count', 'rooms_count', 'year_of_construction']  #


for columni in to_int_columns:
  df[columni] = df[columni].astype(int)

# %%
df.dtypes
# Out:
# author                   object
# author_type              object
# location                 object
# deal_type                object
# accommodation_type       object
# floor                     int64
# floors_count              int64
# rooms_count               int64
# total_meters            float64
# price                   float64
# year_of_construction      int64
# object_type              object
# have_loggia              object
# parking_type             object
# living_meters           float64
# kitchen_meters          float64
# ceiling_height          float64
# district                 object
# street                   object
# underground              object
# residential_complex      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9575 entries, 0 to 10390
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9575 non-null   object
#  1   author_type           9575 non-null   object
#  2   location              9575 non-null   object
#  3   deal_type             9575 non-null   object
#  4   accommodation_type    9575 non-null   object
#  5   floor                 9575 non-null   int64
#  6   floors_count          9575 non-null   int64
#  7   rooms_count           9575 non-null   int64
#  8   total_meters          9575 non-null   float64
#  9   price                 9575 non-null   float64
#  10  year_of_construction  9575 non-null   int64
#  11  object_type           9575 non-null   object
#  12  have_loggia           9575 non-null   object
#  13  parking_type          9575 non-null   object
#  14  living_meters         9575 non-null   float64
#  15  kitchen_meters        9575 non-null   float64
#  16  ceiling_height        9575 non-null   float64
#  17  district              9575 non-null   object
#  18  street                9575 non-null   object
#  19  underground           9575 non-null   object
#  20  residential_complex   9575 non-null   object
# dtypes: float64(5), int64(4), object(12)
# memory usage: 1.9+ MB

# %%
df.head(50)
# Out:
#                                author        author_type  location deal_type  \
# 0                        ID 115709096          homeowner  Серпухов      sale
# 1   Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                          ID 3246838            realtor  Серпухов      sale
# 3                         ID 64398571            unknown  Серпухов      sale
# 4                           ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
# 5                         Максим Юсов  real_estate_agent  Серпухов      sale
# 6                          ID 9655060            unknown  Серпухов      sale
# 7                      Этажи Серпухов  real_estate_agent  Серпухов      sale
# 8                     Ольга Протченко            realtor  Серпухов      sale
# 9                         Глеб Маслов            realtor  Серпухов      sale
# 10                  Людмила Горбачева            realtor  Серпухов      sale
# 11                         KENSINGTON  real_estate_agent  Серпухов      sale
# 12                        ID 12882449          homeowner  Серпухов      sale
# 13                    Монолит Столица  real_estate_agent  Серпухов      sale
# 14                      Евгений Цопин            realtor  Серпухов      sale
# 15                             Сириус  real_estate_agent  Серпухов      sale
# 16                      ПОРТАЛ ЭСТЕЙТ  real_estate_agent  Серпухов      sale
# 17                      Павел Конорев            realtor  Серпухов      sale
# 18                 Shmigirilov Estate  real_estate_agent  Серпухов      sale
# 19                             Гарант  real_estate_agent  Серпухов      sale
# 20                       ID 101407752          homeowner  Серпухов      sale
# 21                      ПОРТАЛ ЭСТЕЙТ  real_estate_agent  Серпухов      sale
# 22  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 23                             Города  real_estate_agent  Серпухов      sale
# 24                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
# 25          Российский аукционный дом  real_estate_agent  Серпухов      sale
# 26                        ID 76236717          homeowner  Серпухов      sale
# 27                       ID 119750928          homeowner  Серпухов      sale
# 28                  Екатерина Шведова            realtor  Серпухов      sale
# 29      Первое агентство недвижимости  real_estate_agent  Серпухов      sale
# 30                     Этажи Серпухов  real_estate_agent  Серпухов      sale
# 31                   Мир Недвижимости  real_estate_agent  Серпухов      sale
# 32                        ID 47582694          homeowner  Серпухов      sale
# 33                     Этажи Серпухов  real_estate_agent  Серпухов      sale
# 34                    Сергей Михайлов            realtor  Серпухов      sale
# 35                        ID 13121751            realtor  Серпухов      sale
# 36                    Сергей Михайлов            realtor  Серпухов      sale
# 37                                ДОМ  real_estate_agent  Серпухов      sale
# 39                Портал Недвижимости  real_estate_agent  Серпухов      sale
# 40                       ID 111337299          homeowner  Серпухов      sale
# 41                        ID 19536560            realtor  Серпухов      sale
# 42                            Домовой  real_estate_agent  Серпухов      sale
# 43                        ID 72566451          homeowner  Серпухов      sale
# 44                       Самолет плюс  real_estate_agent  Серпухов      sale
# 45                   Мир Недвижимости  real_estate_agent  Серпухов      sale
# 46                            Спутник  real_estate_agent  Серпухов      sale
# 47                      Ольга Скалаух            realtor  Серпухов      sale
# 48                   Мир Недвижимости  real_estate_agent  Серпухов      sale
# 49                      Ольга Туренко            realtor  Серпухов      sale
# 50                            РОСБАНК  real_estate_agent  Серпухов      sale
#
#    accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0                flat      6             6            1         20.70
# 1                flat      1             9            1         33.00
# 2                flat      4             4            1         14.00
# 3                flat      5             5            1         17.50
# 4                flat      4             7            1         25.90
# 5                flat      2             3            1         46.70
# 6                flat      3             5            1         29.00
# 7                flat      3             6            1         19.10
# 8                flat      1             2            1         27.10
# 9                flat      6             9            2         42.70
# 10               flat      1             5            2         42.80
# 11               flat      3             4            1         47.00
# 12               flat     15            17            1         20.55
# 13               flat      1             3            1         25.30
# 14               flat      2             3            1         36.00
# 15               flat      1             3            1         22.40
# 16               flat      2             3            2         42.00
# 17               flat      2             4            1         41.40
# 18               flat      2             2            1         31.30
# 19               flat      5             5            1         31.00
# 20               flat      1             2            1         32.10
# 21               flat      2             5            2         47.50
# 22               flat      2             3            1         27.00
# 23               flat      6             6            1         38.90
# 24               flat      2             5            1         29.00
# 25               flat      1             2            3        141.90
# 26               flat      8            10            3         64.00
# 27               flat      8             9            3         60.00
# 28               flat      3            10            3         62.10
# 29               flat      3             5            3         67.20
# 30               flat      7            24            3         77.60
# 31               flat      6             9            3         62.00
# 32               flat      5            10            3         63.00
# 33               flat      1             5            3         57.90
# 34               flat      1             2            3         56.00
# 35               flat      7            10            3         65.00
# 36               flat      2             5            3         54.00
# 37               flat      1             5            3         67.00
# 39               flat      4             5            2         45.50
# 40               flat      1             1            2         46.00
# 41               flat      7             9            2         42.90
# 42               flat      2            14            2         38.40
# 43               flat      1             9            2         48.00
# 44               flat      2             2            2         71.30
# 45               flat      2             5            2         47.00
# 46               flat      4            14            2         64.00
# 47               flat      1             2            2         40.00
# 48               flat      2             5            2         47.00
# 49               flat      6             6            2         56.80
# 50               flat      1             5            2         44.70
#
#          price  ...             object_type have_loggia parking_type  \
# 0    2350000.0  ...                Вторичка     unknown     Наземная
# 1    4150000.0  ...                Вторичка     unknown      unknown
# 2    1700000.0  ...                Вторичка     unknown      unknown
# 3    2500000.0  ...                Вторичка     unknown      unknown
# 4    3000000.0  ...                Вторичка     unknown     Наземная
# 5    6599999.0  ...                Вторичка     unknown      unknown
# 6    3350000.0  ...                Вторичка     unknown     Наземная
# 7    3600000.0  ...                Вторичка     unknown      unknown
# 8    1900000.0  ...                Вторичка     unknown     Наземная
# 9    3990000.0  ...                Вторичка    1 лоджия     Наземная
# 10   2999000.0  ...                Вторичка    1 балкон     Наземная
# 11   1980000.0  ...                Вторичка    1 балкон     Наземная
# 12   2600000.0  ...             Новостройка    1 лоджия     Наземная
# 13   2500000.0  ...                Вторичка    1 лоджия      unknown
# 14   2790000.0  ...                Вторичка     unknown      unknown
# 15   2600000.0  ...                Вторичка    1 лоджия      unknown
# 16   3200000.0  ...                Вторичка     unknown     Наземная
# 17   2800000.0  ...                Вторичка    1 балкон     Наземная
# 18   2700000.0  ...                Вторичка     unknown     Наземная
# 19   3090000.0  ...                Вторичка    1 балкон     Наземная
# 20   2600000.0  ...                Вторичка     unknown     Наземная
# 21   2600000.0  ...                Вторичка    1 балкон     Наземная
# 22   2500000.0  ...                Вторичка     unknown      unknown
# 23   2800000.0  ...                Вторичка    1 лоджия      unknown
# 24   3100000.0  ...                Вторичка     unknown      unknown
# 25   3081000.0  ...                Вторичка     unknown      unknown
# 26   7450000.0  ...                Вторичка    1 лоджия     Наземная
# 27   6600000.0  ...                Вторичка    1 лоджия      unknown
# 28   7300000.0  ...                Вторичка    1 балкон      unknown
# 29   7999000.0  ...                Вторичка    3 лоджии     Наземная
# 30  12700000.0  ...  Вторичка / Апартаменты    1 балкон      unknown
# 31   7350000.0  ...                Вторичка    1 лоджия      unknown
# 32   7600000.0  ...                Вторичка    1 лоджия      unknown
# 33   5750000.0  ...                Вторичка     unknown      unknown
# 34   5490000.0  ...                Вторичка     unknown     Наземная
# 35   8800000.0  ...                Вторичка     unknown      unknown
# 36   5400000.0  ...                Вторичка     unknown      unknown
# 37   8300000.0  ...                Вторичка    1 лоджия     Наземная
# 39   5380000.0  ...                Вторичка    1 балкон     Наземная
# 40   3650000.0  ...                Вторичка     unknown     Наземная
# 41   4500000.0  ...                Вторичка    1 балкон     Наземная
# 42   6700000.0  ...                Вторичка    2 лоджии     Наземная
# 43   4200000.0  ...                Вторичка     unknown      unknown
# 44   6700000.0  ...                Вторичка    1 лоджия      unknown
# 45   4999999.0  ...                Вторичка    1 лоджия      unknown
# 46   9200000.0  ...                Вторичка    1 лоджия     Наземная
# 47   3700000.0  ...                Вторичка     unknown     Наземная
# 48   4050000.0  ...                Вторичка    1 балкон      unknown
# 49   4950000.0  ...                Вторичка     unknown     Наземная
# 50   3900000.0  ...                Вторичка     unknown      unknown
#
#    living_meters  kitchen_meters  ceiling_height                 district  \
# 0           18.0             1.0            3.00                 Серпухов
# 1           18.0             6.0            2.70                  unknown
# 2           25.0             9.5            2.75  Красный Текстильщик мкр
# 3           25.0             9.5            2.75                 Серпухов
# 4           20.0             5.0            3.50                 Серпухов
# 5           25.0             6.0            2.75                 Серпухов
# 6           25.0             9.5            3.00                 Серпухов
# 7           25.0             9.5            2.75                 Серпухов
# 8           18.0             6.0            2.50                  unknown
# 9           29.7             5.6            2.70                 Серпухов
# 10          24.9             6.0            2.50             пос. Чехов-8
# 11          25.0            16.0            2.90                  unknown
# 12          13.4             3.0            2.75          мкр. Востряково
# 13          14.1             6.2            2.80             д. Ворщиково
# 14          25.0             9.5            2.75                    Чехов
# 15          25.0             9.5            2.75                    Чехов
# 16          28.0             6.0            2.75                  unknown
# 17          20.0             7.0            2.75                  unknown
# 18          25.0             5.0            2.75                д. Рыбаки
# 19          15.0             7.3            2.75             с. Ильинское
# 20          25.0             6.1            2.50               д. Дубнево
# 21          28.0             6.0            2.40                  unknown
# 22          19.0             3.0            2.50  Красный Текстильщик мкр
# 23          16.0            10.0            2.80              д. Городище
# 24          19.0             6.0            2.50                 Серпухов
# 25          25.0             9.5            2.75                 Серпухов
# 26          25.0             9.0            2.80                 Серпухов
# 27          40.0             9.0            2.60                 Серпухов
# 28          45.0             9.0            2.80                 Серпухов
# 29          50.0            10.0            2.75                 Серпухов
# 30          25.0             5.0            2.75                 Серпухов
# 31          44.0             8.0            2.65                 Серпухов
# 32          25.0             8.0            2.75                 Серпухов
# 33          25.0             5.0            2.75                 Серпухов
# 34          40.0             6.0            2.80                 Серпухов
# 35          25.0             9.5            2.75                 Серпухов
# 36          39.0             6.0            2.75                 Серпухов
# 37          41.0             9.0            2.50                 Серпухов
# 39          32.5             6.0            2.60                 Серпухов
# 40          25.0             6.0            2.75                 Серпухов
# 41          27.4             5.7            2.50                 Серпухов
# 42          17.0            11.0            2.75                 Серпухов
# 43          25.0            11.0            2.75                 Серпухов
# 44          28.0             8.0            2.75                 Серпухов
# 45          33.0             7.5            2.70                 Серпухов
# 46          39.0            13.5            2.70                 Серпухов
# 47          27.0             5.0            2.50                 Серпухов
# 48          34.0             6.5            2.60                 Серпухов
# 49          30.0            10.0            3.00                 Серпухов
# 50          30.7             5.8            2.75                 Серпухов
#
#                     street underground residential_complex
# 0                  Крюкова     unknown             unknown
# 1               Ворошилова      Аннино             unknown
# 2      Красный Текстильщик     unknown             unknown
# 3              Российская      unknown             unknown
# 4                  Химиков     unknown             unknown
# 5           2-я Московская     unknown             unknown
# 6                   Форсса     unknown             unknown
# 7                  Крюкова     unknown             unknown
# 8                  unknown     unknown             unknown
# 9                Весенняя      unknown             unknown
# 10                   Южная     unknown             unknown
# 11   Художественный проезд  Силикатная             unknown
# 12               Ледовская     unknown           Солнечный
# 13          Солнечный Град     unknown             unknown
# 14                Русская      unknown             unknown
# 15                Русская      unknown             unknown
# 16                 unknown     unknown             unknown
# 17                 unknown     unknown             unknown
# 18                 Садовая     unknown             unknown
# 19               Бригадная     unknown             unknown
# 20              Новые Дома     unknown             unknown
# 21                 unknown     unknown             unknown
# 22     Красный Текстильщик     unknown             unknown
# 23              Молодежная     unknown             unknown
# 24  переулок 1-й Оборонный     unknown             unknown
# 25              Калужская      unknown             unknown
# 26               Звездная      unknown             unknown
# 27              Ворошилова     unknown             unknown
# 28               Звездная      unknown             unknown
# 29       Ивана Болотникова     unknown             unknown
# 30       Борисовское шоссе     unknown             unknown
# 31                 Пушкина     unknown             unknown
# 32                  Новая      unknown             unknown
# 33            Центральная      unknown             unknown
# 34               Захаркина     unknown             unknown
# 35               Весенняя      unknown             unknown
# 36              Лермонтова     unknown             unknown
# 37             Космонавтов     unknown             unknown
# 39              Советская      unknown             unknown
# 40                Водников     unknown             unknown
# 41            Дзержинского     unknown             unknown
# 42              Ворошилова     unknown   по ул. Ворошилова
# 43           проезд Мишина     unknown             unknown
# 44              Советская      unknown             unknown
# 45              Ворошилова     unknown             unknown
# 46             Стадионная      unknown           Жемчужина
# 47            Октябрьская      unknown             unknown
# 48             Подольская      unknown             unknown
# 49            Карла Маркса     unknown             unknown
# 50            Центральная      unknown             unknown
#
# [50 rows x 21 columns]

# %% [markdown]
# После того как были убраны выбросы, можно посчитать цену за квадратный метр

# %%
df['square_price'] = df['price']/df['total_meters']
df.head()
# Out:
#                               author        author_type  location deal_type  \
# 0                       ID 115709096          homeowner  Серпухов      sale
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent  Серпухов      sale
# 2                         ID 3246838            realtor  Серпухов      sale
# 3                        ID 64398571            unknown  Серпухов      sale
# 4                          ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0               flat      6             6            1          20.7
# 1               flat      1             9            1          33.0
# 2               flat      4             4            1          14.0
# 3               flat      5             5            1          17.5
# 4               flat      4             7            1          25.9
#
#        price  ...  have_loggia parking_type living_meters kitchen_meters  \
# 0  2350000.0  ...      unknown     Наземная          18.0            1.0
# 1  4150000.0  ...      unknown      unknown          18.0            6.0
# 2  1700000.0  ...      unknown      unknown          25.0            9.5
# 3  2500000.0  ...      unknown      unknown          25.0            9.5
# 4  3000000.0  ...      unknown     Наземная          20.0            5.0
#
#    ceiling_height                 district                street underground  \
# 0            3.00                 Серпухов               Крюкова     unknown
# 1            2.70                  unknown            Ворошилова      Аннино
# 2            2.75  Красный Текстильщик мкр   Красный Текстильщик     unknown
# 3            2.75                 Серпухов           Российская      unknown
# 4            3.50                 Серпухов               Химиков     unknown
#
#   residential_complex   square_price
# 0             unknown  113526.570048
# 1             unknown  125757.575758
# 2             unknown  121428.571429
# 3             unknown  142857.142857
# 4             unknown  115830.115830
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['author', 'author_type', 'location', 'deal_type', 'accommodation_type',
#        'floor', 'floors_count', 'rooms_count', 'total_meters', 'price',
#        'year_of_construction', 'object_type', 'have_loggia', 'parking_type',
#        'living_meters', 'kitchen_meters', 'ceiling_height', 'district',
#        'street', 'underground', 'residential_complex', 'square_price'],
#       dtype='object')

# %% [markdown]
# # Визуализация

# %%
# @title total_meters vs price

from matplotlib import pyplot as plt
possible_outliers.plot(kind='scatter', x='total_meters', y='price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
ot = df.groupby('object_type')['square_price'].mean().reset_index()
ot = ot[~ot['object_type'].isin(['object_type', 'unknown'])]
ot
# Out:
#                  object_type  square_price
# 2                   Вторичка  1.920162e+05
# 3     Вторичка / Апартаменты  5.470119e+05
# 4        Вторичка / Пентхаус  5.906237e+05
# 5                Новостройка  2.684517e+05
# 6  Новостройка / Апартаменты  5.569049e+05
# 7     Новостройка / Пентхаус  1.252584e+06

# %% [markdown]
# Здесь можно заметить, что дороже всего Новостройка / Пентхаус, а Вторички стоят дешевле всего

# %%
sns.barplot(x='square_price', y='object_type', data=ot, width=1.5)  # Увеличиваем ширину столбцов до 120%
plt.title('Средняя цена по типу жилья')
plt.xticks(rotation=100)  # Поворот подписей по оси X для лучшей читаемости
plt.show()

# %% [markdown]
# Выбираем промежуток от 1990 до 2024

# %%
df = df[(df["year_of_construction"] >= 1990) & (df["year_of_construction"] <= 2024)]

# %%
average_prices = df.groupby('year_of_construction')['square_price'].mean().reset_index()
average_prices
# Out:
#     year_of_construction   square_price
# 0                   1990  170812.726497
# 1                   1991  148960.318219
# 2                   1992  152699.146919
# 3                   1993  159935.557969
# 4                   1994  166093.452140
# 5                   1995  158686.669289
# 6                   1996  175398.227363
# 7                   1997  166334.383012
# 8                   1998  222797.980119
# 9                   1999  197353.764013
# 10                  2000  221619.361229
# 11                  2001  213539.191207
# 12                  2002  197462.419908
# 13                  2003  203134.866124
# 14                  2004  179683.824250
# 15                  2005  214311.527753
# 16                  2006  211736.895588
# 17                  2007  179011.207914
# 18                  2008  214532.319317
# 19                  2009  179481.310062
# 20                  2010  192828.065021
# 21                  2011  178525.372050
# 22                  2012  196127.542492
# 23                  2013  160958.465167
# 24                  2014  201265.383101
# 25                  2015  195395.533765
# 26                  2016  203239.101860
# 27                  2017  260770.361856
# 28                  2018  232552.956977
# 29                  2019  248930.122788
# 30                  2020  227222.419200
# 31                  2021  320434.788679
# 32                  2022  259257.484184
# 33                  2023  333109.419078
# 34                  2024  342664.855837

# %% [markdown]
# Это график который показывает сколько и в какой год стоил 1 квадратный метр

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 6))
sns.barplot(x='year_of_construction', y='square_price', data=average_prices)
plt.title('Средняя цена за кв метр по году')
plt.xlabel('Год')
plt.ylabel('Средняя цена ц\м')
plt.xticks(rotation=110)

plt.show()

# %%
df['year_of_construction'].sort_values(ascending=False)
# Out:
# 4814    2024
# 8175    2024
# 922     2024
# 925     2024
# 928     2024
#         ...
# 6321    1990
# 1097    1990
# 5293    1990
# 7946    1990
# 3217    1990
# Name: year_of_construction, Length: 6695, dtype: int64

# %%
df.describe()
# Out:
#              floor  floors_count  rooms_count  total_meters         price  \
# count  6695.000000   6695.000000  6695.000000   6695.000000  6.695000e+03
# mean      7.693652     14.394922     1.684690     52.773041  1.461356e+07
# std       6.661125      9.053536     0.756545     28.313304  3.827699e+07
# min       1.000000      1.000000    -1.000000     12.000000  8.300000e+05
# 25%       3.000000      8.000000     1.000000     37.800000  5.600000e+06
# 50%       6.000000     15.000000     2.000000     46.100000  8.000000e+06
# 75%      11.000000     18.000000     2.000000     61.000000  1.128000e+07
# max      82.000000    125.000000     5.000000    588.100000  1.058580e+09
#
#        year_of_construction  living_meters  kitchen_meters  ceiling_height  \
# count           6695.000000    6695.000000     6695.000000     6695.000000
# mean            2015.660194      27.085810       10.685273        2.790580
# std                5.825722      12.861501        4.887987        0.340753
# min             1990.000000       3.000000        1.000000        1.650000
# 25%             2016.000000      22.400000        9.500000        2.750000
# 50%             2016.000000      25.000000        9.500000        2.750000
# 75%             2017.000000      27.900000       11.000000        2.750000
# max             2024.000000     300.000000       90.000000       25.000000
#
#        square_price
# count  6.695000e+03
# mean   2.242767e+05
# std    2.377222e+05
# min    2.171247e+04
# 25%    1.334393e+05
# 50%    1.661074e+05
# 75%    2.155713e+05
# max    3.670888e+06

# %% [markdown]
# Максимальная и Минимальная цена

# %%
min_year = average_prices.loc[average_prices['square_price'].idxmin(), 'year_of_construction']
max_year = average_prices.loc[average_prices['square_price'].idxmax(), 'year_of_construction']

min_price = average_prices['square_price'].min()
max_price = average_prices['square_price'].max()

print(f"Минимальная цена: {min_price} в: {min_year}")
print(f"Максимальная цена: {max_price} в: {max_year}")
# Out:
# Минимальная цена: 148960.3182192496 в: 1991
# Максимальная цена: 342664.85583735694 в: 2024

# %%
df.head()
# Out:
#                author        author_type  location deal_type  \
# 2          ID 3246838            realtor  Серпухов      sale
# 4           ЛИДЕРМЭЙН  real_estate_agent  Серпухов      sale
# 5         Максим Юсов  real_estate_agent  Серпухов      sale
# 10  Людмила Горбачева            realtor  Серпухов      sale
# 13    Монолит Столица  real_estate_agent  Серпухов      sale
#
#    accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 2                flat      4             4            1          14.0
# 4                flat      4             7            1          25.9
# 5                flat      2             3            1          46.7
# 10               flat      1             5            2          42.8
# 13               flat      1             3            1          25.3
#
#         price  ...  have_loggia parking_type living_meters kitchen_meters  \
# 2   1700000.0  ...      unknown      unknown          25.0            9.5
# 4   3000000.0  ...      unknown     Наземная          20.0            5.0
# 5   6599999.0  ...      unknown      unknown          25.0            6.0
# 10  2999000.0  ...     1 балкон     Наземная          24.9            6.0
# 13  2500000.0  ...     1 лоджия      unknown          14.1            6.2
#
#     ceiling_height                 district                street underground  \
# 2             2.75  Красный Текстильщик мкр   Красный Текстильщик     unknown
# 4             3.50                 Серпухов               Химиков     unknown
# 5             2.75                 Серпухов        2-я Московская     unknown
# 10            2.50             пос. Чехов-8                 Южная     unknown
# 13            2.80             д. Ворщиково        Солнечный Град     unknown
#
#    residential_complex   square_price
# 2              unknown  121428.571429
# 4              unknown  115830.115830
# 5              unknown  141327.601713
# 10             unknown   70070.093458
# 13             unknown   98814.229249
#
# [5 rows x 22 columns]

# %%
parking = df.groupby('parking_type')['square_price'].mean().reset_index()
parking
# Out:
#      parking_type   square_price
# 0    parking_type  173378.076063
# 1         unknown  205857.304061
# 2  Многоуровневая  308314.614392
# 3        Наземная  176493.832375
# 4        Открытая  211720.969194
# 5       Подземная  508983.706095

# %%
parking = parking[~parking['parking_type'].isin(['parking_type', 'unknown'])]

# %%
parking
# Out:
#      parking_type   square_price
# 2  Многоуровневая  308314.614392
# 3        Наземная  176493.832375
# 4        Открытая  211720.969194
# 5       Подземная  508983.706095

# %% [markdown]
# По этому графику можно увидеть, что дороже всего подземная парковка

# %%
figsize = (12, 1.2 * len(parking['parking_type'].unique()))
plt.figure(figsize=figsize)

# Создание barplot
sns.barplot(data=parking, x='square_price', y='parking_type', palette='Dark2', estimator=np.mean)

# Удаление лишних осей
sns.despine(top=True, right=True, bottom=True, left=True)

# Вывод графика
plt.show()
# Out:
# <ipython-input-73-f563f7ac96b1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=parking, x='square_price', y='parking_type', palette='Dark2', estimator=np.mean)

# %%
logia = df.groupby('have_loggia')['square_price'].mean().reset_index()
logia
# Out:
#             have_loggia   square_price
# 0              1 балкон  187821.786492
# 1              1 лоджия  178038.914624
# 2    1 лоджия, 1 балкон  188155.833325
# 3   1 лоджия, 2 балкона  240594.890229
# 4             2 балкона  277216.014645
# 5              2 лоджии  180104.062242
# 6    2 лоджии, 1 балкон  195778.806601
# 7   2 лоджии, 2 балкона  284786.290426
# 8             3 балкона  425281.160007
# 9              3 лоджии  182024.754104
# 10            4 балкона  982905.982906
# 11             4 лоджии  136402.114071
# 12          have_loggia  173378.076063
# 13              unknown  255168.175511

# %%
logia = logia[~logia['have_loggia'].isin(['have_loggia', 'unknown'])]

# %%
logia
# Out:
#             have_loggia   square_price
# 0              1 балкон  187821.786492
# 1              1 лоджия  178038.914624
# 2    1 лоджия, 1 балкон  188155.833325
# 3   1 лоджия, 2 балкона  240594.890229
# 4             2 балкона  277216.014645
# 5              2 лоджии  180104.062242
# 6    2 лоджии, 1 балкон  195778.806601
# 7   2 лоджии, 2 балкона  284786.290426
# 8             3 балкона  425281.160007
# 9              3 лоджии  182024.754104
# 10            4 балкона  982905.982906
# 11             4 лоджии  136402.114071

# %% [markdown]
# Как влияет на цену за кв.м наличие балконов или лоджии

# %%
figsize = (12, 1.2 * len(logia['have_loggia'].unique()))
plt.figure(figsize=figsize)

# Создание barplot
sns.barplot(data=logia, x='square_price', y='have_loggia', palette='Dark2', estimator=np.mean)

# Удаление лишних осей
sns.despine(top=True, right=True, bottom=True, left=True)

# Вывод графика
plt.show()
# Out:
# <ipython-input-77-f05a8f42de64>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=logia, x='square_price', y='have_loggia', palette='Dark2', estimator=np.mean)

# %%
locations = df.groupby('location')['square_price'].mean().reset_index()
locations
# Out:
#          location   square_price
# 0        location  173378.076063
# 1         unknown  173378.076063
# 2        Балашиха  166068.342657
# 3        Бекасово  368883.639082
# 4          Видное  183091.536309
# 5     Волоколамск  113137.312350
# 6     Воскресенск   98497.887312
# 7     Дзержинский  165378.438737
# 8         Дмитров  121703.209628
# 9    Долгопрудный  204954.944353
# 10     Домодедово  160612.293584
# 11          Дубна  174471.494870
# 12      Жуковский  151016.336817
# 13     Звенигород  136678.677162
# 14     Ивантеевка  583981.527707
# 15           Клин  132293.949687
# 16        Коломна  125341.208102
# 17        Королёв  187839.866423
# 18     Котельники  262437.722166
# 19    Красногорск  234166.976534
# 20  Краснозаводск   85862.759893
# 21          Лобня  165027.890501
# 22        Люберцы  202819.769860
# 23         Москва  664878.250514
# 24         Мытищи  185522.724864
# 25        Ногинск  408791.688402
# 26       Пересвет  288995.271471
# 27        Пушкино  472829.054422
# 28      Раменское  143430.776181
# 29         Реутов  221291.840816
# 30           Руза  109978.470064
# 31       Серпухов  114930.867930
# 32         Талдом  103378.283093
# 33        Талодом  714492.379736
# 34         Троицк  620916.184253
# 35        Фрязино  139701.726848
# 36          Химки  195484.677952
# 37       Хотьково  129422.041372
# 38   Черноголовка  145134.188630
# 39         Шатура  111806.602593
# 40        Щёлково  147257.663880
# 41   Электросталь  123450.419782
# 42         Яхрома  116698.728829
# 43        Яхромаа  341980.073028
# 44         москва  158721.856156

# %%
locations = locations[~locations['location'].isin(['location', 'unknown'])]

# %% [markdown]
# Цена за 1 квадратный метр в зависимости от города

# %%
figsize = (12, 1.2 * len(locations['location'].unique()))
plt.figure(figsize=figsize)

# Создание barplot
sns.barplot(data=locations, x='square_price', y='location', palette='Dark2', estimator=np.mean)

# Удаление лишних осей
sns.despine(top=True, right=True, bottom=True, left=True)

# Вывод графика
plt.show()
# Out:
# <ipython-input-81-71c7de05a253>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=locations, x='square_price', y='location', palette='Dark2', estimator=np.mean)

# %% [markdown]
# **Топ 10 городов по стоимости**

# %%
top_10_locations = locations.sort_values(by='square_price', ascending=False).head(10)

# Устанавливаем размер фигуры
figsize = (12, 1.2 * len(top_10_locations))
plt.figure(figsize=figsize)

# Создание barplot для топ 10 городов
sns.barplot(data=top_10_locations, x='square_price', y='location', palette='Dark2', estimator=np.mean)

# Удаление лишних осей
sns.despine(top=True, right=True, bottom=True, left=True)

# Вывод графика
# Out:
# <ipython-input-82-ed9461c10eb1>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_locations, x='square_price', y='location', palette='Dark2', estimator=np.mean)

# %% [markdown]
# # Зависимости

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
ordinal_encoder = OrdinalEncoder()
encoded_data = ordinal_encoder.fit_transform(df[categorical_columns])
df[categorical_columns] = encoded_data.astype(int)
df
# Out:
#        author  author_type  location  deal_type  accommodation_type  floor  \
# 2         816            5        31          1                   1      4
# 4        2159            4        31          1                   1      4
# 5        2247            4        31          1                   1      2
# 10       2197            5        31          1                   1      1
# 13       2329            4        31          1                   1      1
# ...       ...          ...       ...        ...                 ...    ...
# 10386       1            1         4          1                   1     23
# 10387    2679            5         4          1                   1      1
# 10388      34            4         4          1                   1      8
# 10389    2750            4         4          1                   1      3
# 10390       1            1         4          1                   1     23
#
#        floors_count  rooms_count  total_meters       price  ...  have_loggia  \
# 2                 4            1          14.0   1700000.0  ...           13
# 4                 7            1          25.9   3000000.0  ...           13
# 5                 3            1          46.7   6599999.0  ...           13
# 10                5            2          42.8   2999000.0  ...            0
# 13                3            1          25.3   2500000.0  ...            1
# ...             ...          ...           ...         ...  ...          ...
# 10386            24            1          38.5   9363008.0  ...           13
# 10387             3            2          43.3   5750000.0  ...           13
# 10388             8            2          60.0   9200000.0  ...           13
# 10389            19            2          58.0   8200000.0  ...           13
# 10390            25            2          59.5  14845250.0  ...           13
#
#        parking_type  living_meters  kitchen_meters  ceiling_height  district  \
# 2                 1           25.0             9.5            2.75        96
# 4                 3           20.0             5.0            3.50       189
# 5                 1           25.0             6.0            2.75       189
# 10                3           24.9             6.0            2.50       351
# 13                1           14.1             6.2            2.80       252
# ...             ...            ...             ...             ...       ...
# 10386             1           25.0             9.5            2.75         2
# 10387             1           25.0             9.5            2.75         2
# 10388             1           25.0             9.5            2.75         2
# 10389             1           25.0             9.5            2.75         2
# 10390             1           25.0             9.5            2.75         2
#
#        street  underground  residential_complex   square_price
# 2         267            1                  110  121428.571429
# 4         530            1                  110  115830.115830
# 5           9            1                  110  141327.601713
# 10        564            1                  110   70070.093458
# 13        480            1                  110   98814.229249
# ...       ...          ...                  ...            ...
# 10386    1157           22                    3  243195.012987
# 10387     988          252                  110  132794.457275
# 10388     701           29                  182  153333.333333
# 10389     784           61                  751  141379.310345
# 10390    1157           22                    3  249500.000000
#
# [6695 rows x 22 columns]

# %%
plt.figure(figsize = (25,20))
sns.heatmap(df.corr().round(2), cmap="crest", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Данные корреляции в столбик:

# %%
corr_matrix = df.corr()['square_price'].round(2)
sort = corr_matrix.sort_values(ascending=False)
print(sort)
# Out:
# square_price            1.00
# price                   0.81
# total_meters            0.41
# kitchen_meters          0.27
# floors_count            0.24
# object_type             0.23
# parking_type            0.21
# floor                   0.18
# living_meters           0.17
# underground             0.17
# rooms_count             0.15
# have_loggia             0.15
# ceiling_height          0.15
# year_of_construction    0.14
# district                0.13
# residential_complex     0.03
# location                0.02
# accommodation_type     -0.00
# deal_type              -0.00
# street                 -0.02
# author_type            -0.07
# author                 -0.14
# Name: square_price, dtype: float64

# %% [markdown]
# Больше всего вляет на square_price total_meters
#
# Также положительную корреляцию имеют такие признаки как:
#
#
# ```
# square_price            1.00
# price                   0.81
# total_meters            0.41
# kitchen_meters          0.27
# floors_count            0.24
# object_type             0.23
# parking_type            0.21
# floor                   0.18
# living_meters           0.17
# underground             0.17
# rooms_count             0.15
# have_loggia             0.15
# ceiling_height          0.15
# year_of_construction    0.14
# district                0.13
# residential_complex     0.03
# location                0.02
#
#
# ```

# %% [markdown]
# # Выводы по анализу:
#
#
# Больше всего на цену за квадратный метр в порядке убывания влияют: цена, общая площадь, площадь кухни, количество этажей, тип жилья (Новостройка / Вторичка и их подвиды), тип парковки, этаж, жилая площадь, метро, количество комнат, наличие лоджии или балкона, высота потолка, год постройки, район, жилой комплекс и город.
#
#
#
# *Все эти признаки будут учитываться при построении модели*
#
#
# **Выводы по графикам**
#
#
#
#
#
# ---
#
#
#
# 📉  Минимальная цена: 148960.3182192496 в: 1991
#
# ---
#
#
# 📈  Максимальная цена: 342664.85583735694 в: 2024
#
#
# ---
#
#
#
#
#
#
#
#     ✅ дороже всего стоят Новостройки / Пентахаусы, самые дешевые - Вторички
#
#     ✅ Подземная парковка самая дорогая, а наземная - дешевая
#
#     ✅ Балконы по сравнению с лоджиями намного превышают значение цены
#
#
# **Топ 10 городов по стоимости:**
#
#
#         ⭐ Талдом
#         ⭐ Москва
#         ⭐ Троицк
#         ⭐ Ивантеевка
#         ⭐ Пушкино
#         ⭐ Ногинск
#         ⭐ Бекасово
#         ⭐ Яхрома
#         ⭐ Пересвет
#         ⭐ Котельники

# %% [markdown]
# # Выводы по проделанной работе и планы

# %% [markdown]
# **Сделано:**
#
#     ✅ Загрузила и очистила данные от дубликатов
#
#
#     ✅ Преобразовала тип данных некоторых колонок из object в int и float
#
#
#     ✅ Посмотрела на выбросы, очистила от выбросов и проанализировала те выбросы, которые не видны на графиках
#
#
#
#     ✅ Заполнила нулевые значения медианой, модой, а остальные 'unknown'
#
#
#     ✅ Добавила колонку `'square_price'`, главную целевую переменную
#
#
#     ✅ Визуализировала данные с помощью графиков, и вывела графики цены за квадратный метр в завивисимости от типа жилья, года, типа парковки, и локации
#
#
#     ✅ Вывела матрицу корреляций и определила главные признаки, влияющие на целевую переменную `'square_price'`
#
#
# **Не сделано / сделано плохо:**
#
#     ❌ Пришлось удалить те колонки, которые могли бы влиять на цену за квадратный метр: это тип отделки и тип отопления. Значения в них отсутствовали на 80% и более
#
#
#     ❌ Судя по всему, часть выбросов, пусть даже и небольшая, все равно осталась в данных. Это может повлиять в дальнейшем на точность модели
#
#
#     ❌ Статистика по городам выглядит неправдоподобной, Москва всего лишь на 2-м месте. Это можно объяснить малым количеством данных или выбросами
#
#
#
#
# **❗ В планах:**
#
#       ❗ Построить модель
